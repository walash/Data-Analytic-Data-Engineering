# %% [markdown]
# # 02 · Predictive Modelling
#
# Train / inspect the patient-deterioration models.
#
# > Run modelling first: `python main.py --pipeline modeling`

# %%
import sys, os
sys.path.append(os.path.abspath('..'))
import pandas as pd
from src.utils.common import get_paths
paths = get_paths()

# %% [markdown]
# ## Model comparison

# %%
ev = pd.read_csv(paths['reports'] / 'model_evaluation.csv')
ev.sort_values('f1', ascending=False)

# %% [markdown]
# ## Selected features

# %%
pd.read_csv(paths['reports'] / 'selected_features.csv')

# %% [markdown]
# ## Feature importance (XGBoost)

# %%
pd.read_csv(paths['reports'] / 'feature_importance_xgboost.csv').head(15)

# %% [markdown]
# ## Inference example

# %%
from src.modeling.deterioration_predictor import DeteriorationPredictor
from src.modeling.common import load_modeling_frame
predictor = DeteriorationPredictor()
sample = load_modeling_frame().head(5)
predictor.batch_predict(sample)[['patient_id','deterioration_proba','risk_band']]
